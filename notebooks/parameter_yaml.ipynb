# %%
import meappy.parameter_yaml as py
from meappy.parameter_yaml import USER, USER_PATHS
from meappy.meappy_data import *

# %%
import pandas as pd

# %%
filepath = '/Users/walter/Library/CloudStorage/Box-Box/MED64_shared_data/misc_file_sharing/MED64_ExperimentsForAnalysis.xlsx'

df_pd = pd.read_excel(filepath, engine="openpyxl", sheet_name='LHb')

# %%
df_pd
# Out:
#         Date  Cut by  Run by Recording  Region  Slice Location  Project  \
# 0   20191223     NaN   EM+JM                Hb             NaN      NaN
# 1   20200725     NaN      LH               LHb             NaN      NaN
# 2   20200827     NaN      LH               LHb             NaN      NaN
# 3   20200827     NaN      LH               LHb             NaN      NaN
# 4   20200827     NaN      LH               LHb             NaN      NaN
# 5   20200827     NaN      LH               LHb             NaN      NaN
# 6   20200825     NaN      LH               LHb             NaN      NaN
# 7   20200825     NaN      LH               LHb             NaN      NaN
# 8   20200825     NaN      LH               LHb             NaN      NaN
# 9   20200825     NaN      LH               LHb             NaN      NaN
# 10  20190906     NaN      LH               LHb             NaN      NaN
# 11  20190906     NaN      LH               LHb             NaN      NaN
# 12  20190906     NaN      LH               LHb             NaN      NaN
# 13  20190906     NaN      LH               LHb             NaN      NaN
# 14  20190906     NaN      LH               LHb             NaN      NaN
# 15  20190906     NaN      LH               LHb             NaN      NaN
# 16  20190830     NaN      LH               LHb             NaN      NaN
# 17  20190830     NaN      LH               LHb             NaN      NaN
# 18  20190830     NaN  EM+KAM               LHb             NaN      NaN
# 19  20190830     NaN  EM+KAM               LHb             NaN      NaN
# 20  20190830     NaN     KAM               LHb             NaN      NaN
#
#    Experiment Type          Drugs Used  Vendor/Batch    Slice # Photo saved  \
# 0           BT0006  DNQX, BT139, DAMGO           NaN  15h25m44s         NaN
# 1           BT0006         DNQX, DAMGO           NaN  14h13m44s         NaN
# 2            BT139         DNQX, DAMGO           NaN  15h57m53s         NaN
# 3            BT139         DNQX, DAMGO           NaN  15h40m00s         NaN
# 4            BT139               DAMGO           NaN  13h30m23s         NaN
# 5            BT139         DNQX, DAMGO           NaN  12h06m26s         NaN
# 6            BT139         DNQX, DAMGO           NaN  12h24m37s           Y
# 7            BT139         DNQX, DAMGO           NaN  13h36m25s           Y
# 8            BT139         DNQX, DAMGO           NaN  15h01m13s           Y
# 9            BT139         DNQX, DAMGO           NaN  16h06m19s           Y
# 10           DAMGO                 NaN           NaN  16h44m47s         NaN
# 11           DAMGO                 NaN           NaN  17h21m41s         NaN
# 12           DAMGO                 NaN           NaN  17h58m35s         NaN
# 13      DNQX - AP5                 NaN           NaN  14h29m11s         NaN
# 14      DNQX - AP5                 NaN           NaN  15h18m38s         NaN
# 15      DNQX - AP5                 NaN           NaN  16h03m47s         NaN
# 16           DAMGO                 NaN           NaN  17h20m05s         NaN
# 17           DAMGO                 NaN           NaN  18h02m25s           N
# 18      DNQX - AP5                 NaN           NaN  14h24m59s         NaN
# 19      DNQX - AP5                 NaN           NaN  15h09m44s         NaN
# 20      DNQX - AP5                 NaN           NaN  16h13m42s         NaN
#
#                                 Notes/Problems/Issues  Exported?  Analyzed?  \
# 0                                                 NaN        NaN        NaN
# 1        Good channels: 34, 26, 27, 41 (skipped wash)        NaN        NaN
# 2   Channel 1 is upper left corner of image. Good ...        NaN        NaN
# 3   Overflow dish 2100s Increase DAMGO time. Good ...        NaN        NaN
# 4   Good channels: 28, 29, 30, 37, 46, 21, 44, 14,...        NaN        NaN
# 5   Good channels: 13, 23, 27, 28, 30, 31, 55, 45,...        NaN        NaN
# 6   Good channels: 14, 19, 21, 20, 27, 28, 29, 30,...        NaN        NaN
# 7   Good channels: 18, 22, 23, 31, 27, 39, 40, 50,...        NaN        NaN
# 8               Good channels: 34, 42, 50, 41, 33, 26        NaN        NaN
# 9    Good channels: 9, 17, 18, 26, 27, 28, 35, 43, 44        NaN        NaN
# 10                                                NaN        NaN        NaN
# 11                                                NaN        NaN        NaN
# 12                                                NaN        NaN        NaN
# 13                                                NaN        NaN        NaN
# 14                                                NaN        NaN        NaN
# 15                                                NaN        NaN        NaN
# 16                                                NaN        NaN        NaN
# 17                                                NaN        NaN        NaN
# 18                                                NaN        NaN        NaN
# 19                                                NaN        NaN        NaN
# 20                                                NaN        NaN        NaN
#
#     Notes
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN

# %% [markdown]
# ## TODO:
# - change the example output of this to the test data drive create in meappy_data.py
#
# - Check if this can write to the Box desktop drive directly. That could be useful for easy creation of yaml directory structure

# %%
py.main()
# Out:
# set user to: meappy_data
# Parameter slice params written to: /Users/walter/Src/meap_output/experiment/VTA_EM1_Dose_Response/20211105_15h48m31s/slice_parameters.yaml
# Parameter slice params written to: /Users/walter/Src/meap_output/experiment/VTA_EM1_Dose_Response/20211109_15h09m07s/slice_parameters.yaml
# Parameter slice params written to: /Users/walter/Src/meap_output/experiment/VTA_EM1_Dose_Response/20211109_17h18m41s/slice_parameters.yaml
# Parameter slice params written to: /Users/walter/Src/meap_output/experiment/VTA_EM1_Dose_Response/20211110_15h00m50s/slice_parameters.yaml
# Parameter slice params written to: /Users/walter/Src/meap_output/experiment/VTA_EM1_Dose_Response/20211122_13h47m47s/slice_parameters.yaml
# Parameter slice params written to: /Users/walter/Src/meap_output/experiment/VTA_EM1_Dose_Response/20211130_17h27m13s/slice_parameters.yaml
# Parameter slice params written to: /Users/walter/Src/meap_output/experiment/VTA_EM1_Dose_Response/20211202_18h13m40s/slice_parameters.yaml
# Parameter slice params written to: /Users/walter/Src/meap_output/experiment/VTA_EM1_Dose_Response/20211202_14h49m06s/slice_parameters.yaml
# Parameter protocol written to: /Users/walter/Src/meap_output/experiment/VTA_EM1_Dose_Response/protocol_parameters.yaml
